# %% [markdown]
# Machine Learning aplicado a la predicción de precio de criptomonedas, utilizando valores anteriores de las principales critpomonedas, valores de índices de stocks, y trends de búsqueda.

# %%
# Manipulación de datos
import pandas as pd
import matplotlib.pyplot as plt # Plots

# Keras
from math import sqrt
from sklearn.metrics import mean_squared_error

import Predictor
# Out:
# c:\users\leandro\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
criptomonedas_posibles = ['bitcoin','ethereum','ripple','dash','litecoin',
                     'monero','ethereum-classic','nem','augur',                 
                     'litecoin','cardano','stellar','iota','tron',
                     'neo','dash','bitcoin-cash','eos','vechain',
                     'tether','qtum','omisego','icon','binance-coin',
                     'lisk','bitcoin-gold','bytecoin-bcn','nano','verge',
                     'zcash','aeternity','zilliqa']
top_criptomonedas = ['bitcoin','ethereum','ripple','dash','litecoin','monero','ethereum-classic','nem','augur']
stocks_names=['AAPL','FB','GOOG','GOOGL','IBM','INTC','MSFT','NFLX','ORCL','TSLA']
stockindex_names=['^IXIC','^RUT','^DJI','^GSPC']

# DataManager
dm = Predictor.Data()
#dm.update_datasets(crypto_names=top_criptomonedas,stock_names=stockindex_names,fecha_comienzo='2017-01-01', fecha_fin='2018-05-25')
dm = Predictor.Data('data/data.csv')
#dm.plot()

# %%
'''
Simulaciones
'''
def simulaciones(dataset,ventana,neuronas,epochs,futuro):
    for f in futuro:
        for v in ventana:
            predictor = Predictor.Predictor(dataset)
            for n in neuronas:
                for e in epochs:                
                    predictor = Predictor.Predictor(dataset)
                    p = predictor.entrenar_predecir(test_size=30,window_size=v,dia_futuro=f,neuronas=n,epochs=e, visualizar=1,verbose=0)

# %%
ventana = [1,2]
neuronas = [2]
epochs = [20]
futuro = [1]
monedas = ['bitcoin','ethereum','ripple','dash']

for m in ['bitcoin']:
    print("Moneda: " + m)
    dataset = dm.create_dataset(m,fecha_comienzo=dm.fecha_comienzo,fecha_fin=dm.fecha_fin)
    simulaciones(dataset,ventana,neuronas,epochs,futuro)
# Out:
# Moneda: bitcoin
# New Predictor
# New Predictor
# Datos Preprocesados. Entrenando...
# Predicciones guardadas en carpeta: predicciones/bitcoin/f1v1n2e20
# Entrenamiento guardado en carpeta: predicciones/bitcoin/f1v1n2e20
# RMSE: 2107.028279440745
# New Predictor
# New Predictor
# Datos Preprocesados. Entrenando...
# Predicciones guardadas en carpeta: predicciones/bitcoin/f1v2n2e20
# Entrenamiento guardado en carpeta: predicciones/bitcoin/f1v2n2e20
# RMSE: 1345.6616350407642

# %%
from sklearn.metrics import mean_squared_error

def visualizar_errores(stock,ventana,futuro,neuronas,epochs):
        for f in futuro:        
            plt.figure(figsize=(20,5*len(ventana)*len(neuronas)))
            i = 1
            rmses_y = []
            rmses_x = []
            for v in ventana:  
                    for n in neuronas:
                            file = 'f' + str(f) + 'v' + str(v) + 'n' + str(n)  + 'e' + str(epochs)
                            plt.subplot(len(ventana)*len(neuronas), 2, i)
                            prediccion = pd.read_csv('predicciones/' + stock + '/' + file  + '/predicciones.csv')
                            prediccion.set_index('Date',inplace=True)
                            plt.plot(prediccion)
                            plt.legend(loc='best')
                            rmse = sqrt(mean_squared_error(prediccion[prediccion.columns[0]], prediccion[prediccion.columns[1]]))
                            rmses_y.append(rmse)
                            rmses_x.append(file)  
                            i+=1
                            plt.subplot(len(ventana)*len(neuronas), 2, i)
                            training = pd.read_csv('predicciones/' + stock + '/' + file + '/train_history.csv')
                            plt.plot(training[training.columns[0]], label='loss')
                            plt.plot(training[training.columns[1]], label='val_loss')
                            plt.title(file, fontsize=40)
                            plt.legend()
                            plt.grid(color='grey', linestyle='-', linewidth=0.5)
                            i+=1
            plt.savefig('predicciones/' + stock + '/f' + str(f) + "_training.png")
            plt.show()  
            
            #RMSE
            width = 1/1.5
            plt.figure(figsize=(20,5))
            plt.bar(rmses_x, rmses_y, width)
            plt.xticks(rotation=20)
            plt.title("RMSE")
            plt.savefig('predicciones/' + stock + '/f' + str(f) + "_rmse.png")
            plt.show()    
            
for m in ['bitcoin']:
    visualizar_errores(m,ventana,futuro,neuronas,epochs=20)
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ebb25f0c7f78> in <module>()
#      40
#      41 for m in ['bitcoin']:
# ---> 42     visualizar_errores(m,ventana,futuro,neuronas,epochs=20)
#
# <ipython-input-13-ebb25f0c7f78> in visualizar_errores(stock, ventana, futuro, neuronas, epochs)
#      10                     for n in neuronas:
#      11                             file = 'f' + str(f) + 'v' + str(v) + 'n' + str(n)  + 'e' + str(epochs)
# ---> 12                             plt.subplot(len(ventana)*len(neuronas), 1, i)
#      13                             prediccion = pd.read_csv('predicciones/' + stock + '/' + file  + '/predicciones.csv')
#      14                             prediccion.set_index('Date',inplace=True)
#
# ...

# %% [markdown]
# # Manipulación de datos
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt # Plots
#
# import requests #Scraping
# from bs4 import BeautifulSoup #Scraping
# from pytrends.request import TrendReq #GoogleTrends
#
# # Keras
# from keras.preprocessing.sequence import TimeseriesGenerator
# from keras.layers.core import Dense,Activation,Dropout
# from keras.layers.recurrent import LSTM
# from keras.models import Sequential
# import time
# import warnings
# from sklearn import preprocessing
# from sklearn.metrics import mean_squared_error
# from math import sqrt
#
# #Manejo de archivos
# import os
# import tempfile
# import shutil
#
# dia_futuro = 1
# window_size = 1
# test_size = 30
#
# dataset = dm.data[dm.fecha_comienzo:dm.fecha_fin]
# x = dataset
# y = dataset[['bitcoin']]
#
# train_x = dm.data[0:len(dm.data)-test_size]
# train_y = y[(dia_futuro-1):len(dm.data)-test_size+(dia_futuro-1)]
# test_x = dm.data[len(dm.data)-test_size:len(dm.data)-(dia_futuro-1)]
# test_y = y[['bitcoin']][len(dm.data)-test_size+(dia_futuro-1):]
# real_price = test_y[window_size:]
#
# scalerX = preprocessing.MinMaxScaler(feature_range = (0,1)).fit(train_x)
# train_x_scaled = scalerX.transform(train_x)
# test_x_scaled = scalerX.transform(test_x)
#
# scalerY = preprocessing.MinMaxScaler(feature_range = (0,1)).fit(train_y.values.reshape(-1,1))
# train_y_scaled = scalerY.transform(train_y.values.reshape(-1,1))
# test_y_scaled = scalerY.transform(test_y.values.reshape(-1,1))
#
#
# validation_split = 0.8
# batch_s = 15
# training_sequence = TimeseriesGenerator(train_x_scaled, train_y_scaled,
#                                length=window_size, sampling_rate=1,
#                                 end_index=int(len(train_x)*validation_split),
#                                batch_size=batch_s)
# validation_sequence = TimeseriesGenerator(train_x_scaled, train_y_scaled,
#                                        length=window_size, sampling_rate=1,
#                                         start_index=int(len(train_x)*validation_split), end_index=len(train_x),
#                                        batch_size=batch_s)
# testing_sequence = TimeseriesGenerator(test_x_scaled, test_y_scaled,
#                                        length=window_size, sampling_rate=1,
#                                         end_index=len(test_x),
#                                        batch_size=1)
#
# neuronas = 2
# epochs = 2
# model = Sequential()
# model.add(LSTM(units = neuronas, dropout=0,
#                        input_shape=(training_sequence[0][0].shape[1], #window_size
#                                     training_sequence[0][0].shape[2]))) #features
# model.add(Dense(units = 1, activation = 'linear'))
# model.compile(optimizer = 'adam', loss = 'mean_squared_error')
#
# history = model.fit_generator(training_sequence,
#                                                 validation_data=validation_sequence,
#                                                 epochs=epochs,verbose=1)
#
# predicted = model.predict_generator(testing_sequence)
# predicted = predicted.reshape(-1,1)
# predicted = scalerY.inverse_transform(predicted)
#
# print(predicted)
# real_price['predicted'] = predicted
# print(real_price)
# real_price.to_csv('prediccion')
#
# plt.figure(figsize=(20,5))
# plt.plot(real_price)
# plt.title("Prediccion", fontsize=40)
# plt.legend()
# plt.grid(color='grey', linestyle='-', linewidth=0.5)
# #plt.savefig(self.__datasetfolder + "/entrenamiento.png")
# plt.show()

# %%
''' Simulación de prediccion '''
'''
dm = Data('data/data.csv')
dataset_menos30 = dm.create_dataset(stock='bitcoin',
                                    fecha_comienzo=dm.fecha_comienzo,fecha_fin='2018-02-23',
                                    ventana=0,dia_futuro=1)
dataset_pos30 = dm.create_dataset(stock='bitcoin',
                                    fecha_comienzo='2018-02-24',fecha_fin=dm.fecha_fin,
                                    ventana=0,dia_futuro=1)
#Entrenar la red con los datos disponibles (en esta simulación se dejan los ultimos 30 dias para predecir)
predictor = Predictor(dataset_menos30)
predicciones_45022 =  predictor.entrenar_predecir(neuronas=4,epochs=400,batch_size=150,test_size=30)
predictor.visualizar()

prediccion = predictor.predict(dataset_pos30['x'])
#print(prediccion)
plt.figure(figsize=(20,10))
plt.plot(prediccion, color = (1, 0, 0), label = "Prediccion")
plt.plot(dataset_pos30['y'], color = (0, 0, 1), label = 'Precio Real')
plt.title("Predicción Market Cap BTC", fontsize=40)
plt.legend()
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.show()
'''
# Out:
# '\ndm = Data(\'data/data.csv\')\ndataset_menos30 = dm.create_dataset(stock=\'bitcoin\',\n                                    fecha_comienzo=dm.fecha_comienzo,fecha_fin=\'2018-02-23\',\n                                    ventana=0,dia_futuro=1)\ndataset_pos30 = dm.create_dataset(stock=\'bitcoin\',\n                                    fecha_comienzo=\'2018-02-24\',fecha_fin=dm.fecha_fin,\n                                    ventana=0,dia_futuro=1)\n#Entrenar la red con los datos disponibles (en esta simulación se dejan los ultimos 30 dias para predecir)\npredictor = Predictor(dataset_menos30)\npredicciones_45022 =  predictor.entrenar_predecir(neuronas=4,epochs=400,batch_size=150,test_size=30)\npredictor.visualizar()\n\nprediccion = predictor.predict(dataset_pos30[\'x\'])\n#print(prediccion)\nplt.figure(figsize=(20,10))\nplt.plot(prediccion, color = (1, 0, 0), label = "Prediccion")\nplt.plot(dataset_pos30[\'y\'], color = (0, 0, 1), label = \'Precio Real\')\nplt.title("Predicción Market
# ...
